# %%
import pandas as pd
import numpy as np
from bokeh.plotting import figure
from bokeh.io import output_notebook, show

# %%
x = np.arange(10)
y = np.arange(10,20)

# %%
output_notebook()

# %%
f = figure()

# %%
f.line(x,y)
show(f)
# Out:
#   <div class="bk-root" id="6afcbe35-adfb-4578-97f7-46c1931d14e3" data-root-id="1001"></div>

# %%
x = np.random.normal(size = 100)
y = np.random.normal(size = 100)

f = figure()
f.scatter(x,y)
show(f)
# Out:
#   <div class="bk-root" id="16776c58-d4b2-4c63-a362-ee06294f7429" data-root-id="1527"></div>

# %%
f.triangle(x,y)
show(f)
# Out:
#   <div class="bk-root" id="08d1d994-f1a8-40d6-a696-8f8f96bb68f2" data-root-id="1527"></div>

# %%
f.circle(x,y)
show(f)
# Out:
#   <div class="bk-root" id="cdaa1dca-fe9b-4ec0-b267-a8d6898aa66e" data-root-id="1527"></div>

# %% [markdown]
# Creating a Bokeh chart from a dataframe.

# %%
# Creating a chart from the Pandas DataFrame

df = pd.DataFrame({'x': x,
                   'y': y})
df.head()
# Out:
#           x         y
# 0  1.035188 -1.207973
# 1 -0.011688 -2.244607
# 2  0.586060 -0.082076
# 3 -0.045630 -1.328964
# 4  0.166867  0.514787

# %%
f = figure()
f.circle(df['x'], df['y'])
show(f)
# Out:
#   <div class="bk-root" id="c8777ad7-1e19-4653-ad91-263f25a73afc" data-root-id="1979"></div>

# %% [markdown]
# Creating more charts using the pandas dataframe. In this chart we will download the data from a website. This data show the percentage of women who have received bachelors degree in engineering.

# %%
df = pd.read_csv('http://pythonhow.com/data/bachelors.csv')

# %%
df.head()
# Out:
#    Year  Agriculture  ...  Public Administration  Social Sciences and History
# 0  1970     4.229798  ...                   68.4                         36.8
# 1  1971     5.452797  ...                   65.5                         36.2
# 2  1972     7.420710  ...                   62.6                         36.1
# 3  1973     9.653602  ...                   64.3                         36.4
# 4  1974    14.074623  ...                   66.1                         37.3
#
# [5 rows x 18 columns]

# %%
f = figure()
f.line(df['Year'], df['Engineering'])
show(f)
# Out:
#   <div class="bk-root" id="00dc8127-2f15-4fe3-934c-007adef2083d" data-root-id="2164"></div>

# %% [markdown]
# This is how we can download the file and read the data into pandas as a dataframe. We can use that data frame to draw a line chart using bokeh
